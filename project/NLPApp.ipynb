# %%
import nlpcloud

client = nlpcloud.Client("gpt-oss-120b", "1a260e5d955b2933c02a9d654de116e8a78ab16a", gpu=True)
response = client.entities(
    """John Doe started learning Javascript when he was 15 years old. After a couple of years he switched to Python and starter learning low level programming. He is now a Go expert at Google.""",
    searched_entity="programming languages"
)
# Out:
# {'entities': [{'start': 26, 'end': 36, 'type': 'programming languages', 'text': 'Javascript'}, {'start': 102, 'end': 108, 'type': 'programming languages', 'text': 'Python'}, {'start': 165, 'end': 167, 'type': 'programming languages', 'text': 'Go'}]}
# ['Javascript', 'Python', 'Go']

# %% [markdown]
# ### OOP Project

# %% [markdown]
# NLPAPP

# %%
import nlpcloud

class NLPApp : 

    def __init__(self): 
        self.__database = {}
        self.menu()

    def menu(self) : 
        user_input = input("""
        HELLO! how would you like to procede :
        1.Resgister
        2.Already a member? Login 
        3.exit(galti se aagaya)
        """)
        if user_input == "1": 
            self.register()
        elif user_input == "2": 
            self.login()
        else: 
            exit()
            
    def register(self ): 
        name = input("enter name :")
        email = input("enter email: ")
        password = input("enter password")

        if email in self.__database: 
            print("user already exist . login")
            #self.login()
        else: 
            self.__database[email] = [name, password]
            print ( "registered succesfully")
            print(self.__database)
        self.login()
        
    def login(self): 
        print("now login\n")
        email = input("enter email: ")
        password = input("enter password")

        if email not in self.__database:
            print("user does not exist, register first\n")
            return self.register()

        if self.__database[email][1] == password:
            print("login successfully")
            return self.second_menu()
        else:
            print("wrong password\ntryagain\n")
            return self.login()
                
    def second_menu(self): 
        user_input = input("""
        Hii which function you want to procede
        1. NER (entity extraction)
        2. Language Detection
        3. Sentiment / Emotion Analysis
        4. Exit (kuch nahi kerna)
        """)

        if user_input == "1": 
            self.NER()
        elif user_input ==  "2": 
            self.lang_detection()
        elif user_input == "3": 
            self.sentiment()
        else: 
            return 0

    def NER(self): 
        para = input("enter the paragraph you want to check: ")
        search = input("enter the searching word")
        client = nlpcloud.Client("gpt-oss-120b", "1a260e5d955b2933c02a9d654de116e8a78ab16a", gpu=True)
        response = client.entities(para,searched_entity=search)
        l =[]
        for i in range(len(response["entities"])): 
            text = (response["entities"][i]["text"]) 
            l.append(text)
        print(l)

        
    def lang_detection(self): 
        pass

    def sentiment(self): 
        pass

        
app = NLPApp()
# Out:
#         HELLO! how would you like to procede :
#         1.Resgister
#         2.Already a member? Login
#         3.exit(galti se aagaya)
#          1
# enter name : nikhil
# enter email:  nikhil@gmail.com
# enter password 1234
# registered succesfully
# {'nikhil@gmail.com': ['nikhil', '1234']}
# enter email:  nikhil@gmail.com
# enter password 567
# wrong password
# enter email:  nikhil18@gmail
# enter password 123
# user does not exist, register first
# enter name : khushraj
# enter email:  khushraj@gmail.com
# enter password 2345
# registered succesfully
# {'nikhil@gmail.com': ['nikhil', '1234'], 'khushraj@gmail.com': ['khushraj', '2345']}
# enter email:  khushraj@gmil.com
# enter password 2345
# user does not exist, register first
# enter name : nitish
# enter email:  nitish@gmail.com
# enter password 7890
# registered succesfully
# {'nikhil@gmail.com': ['nikhil', '1234'], 'khushraj@gmail.com': ['khushraj', '2345'], 'nitish@gmail.com': ['nitish', '7890']}
# enter email:  khushraj@gmail.com
# enter password 2345
# login successfully
#         Hii which function you want to procede
#         1. NER (entity extraction)
#         2. Language Detection
#         3. Sentiment / Emotion Analysis
#         4. Exit (kuch nahi kerna)
#          1
# enter the paragraph you want to check:  John Doe started learning Javascript when he was 15 years old. After a couple of years he switched to Python and starter learning low level programming. He is now a Go expert at Google.
# enter the searching word programming language
# ['Javascript', 'Python', 'Go']
# enter email:  bhaiyu@gmail.com
# enter password 1234
# login succesfully
#         Hii which function you want to procede
#         1. NER (entity extraction)
#         2. Language Detection
#         3. Sentiment / Emotion Analysis
#         4. Exit (kuch nahi kerna) 1
# enter the paragraph you want to check:  """John Doe started learning Javascript when he was 15 years old. After a couple of years he switched to Python and starter learning low level programming. He is now a Go expert at Google.""",
# enter the searching word programming language
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\nlpcloud\__init__.py:185, in Client.entities(self, text, searched_entity)
#     184 try:
# --> 185     r.raise_for_status()
#     186 except HTTPError as err:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\requests\models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 429 Client Error: Too Many Requests for url: https://api.nlpcloud.io/v1/gpu/gpt-oss-120b/entities
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# Cell In[16], line 76
#      73     def sentiment(self):
#      74         pass
# ---> 76 app = NLPApp()
#
# Cell In[16], line 5, in NLPApp.__init__(self)
#       3 def __init__(self):
#       4     self.__database = {}
# ----> 5     self.menu()
#
# Cell In[16], line 15, in NLPApp.menu(self)
#       8 user_input = input("""
#       9 HELLO! how would you like to procede :
#      10 1.Resgister
#      11 2.Already a member? Login
#      12 3.exit(galti se aagaya)
#      13 """)
#      14 if user_input == "1":
# ---> 15     self.register()
#      16 elif user_input == "2":
#      17     self.login()
#
# Cell In[16], line 33, in NLPApp.register(self)
#      31     print ( "registered succesfully")
#      32     print(self.__database)
# ---> 33 self.login()
#
# Cell In[16], line 42, in NLPApp.login(self)
#      40 if i == email and self.__database[email][1] == password:
#      41     print("login succesfully")
# ---> 42     self.second_menu()
#      43 else:
#      44     print("usre doesnot exist register first")
#
# Cell In[16], line 56, in NLPApp.second_menu(self)
#      48 user_input = input("""
#      49 Hii which function you want to procede
#      50 1. NER (entity extraction)
#      51 2. Language Detection
#      52 3. Sentiment / Emotion Analysis
#      53 4. Exit (kuch nahi kerna)""")
#      55 if user_input == "1":
# ---> 56     self.NER()
#      57 elif user_input ==  "2":
#      58     self.lang_detection()
#
# Cell In[16], line 68, in NLPApp.NER(self)
#      66 search = input("enter the searching word")
#      67 client = nlpcloud.Client("gpt-oss-120b", "1a260e5d955b2933c02a9d654de116e8a78ab16a", gpu=True)
# ---> 68 response = client.entities(para,searched_entity=search)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\nlpcloud\__init__.py:190, in Client.entities(self, text, searched_entity)
#     187     if "<!DOCTYPE html>" in r.text:
#     188         raise HTTPError(str(err))
# --> 190     raise HTTPError(str(err) + ": " + str(r.text))
#     192 return r.json()
#
# HTTPError: 429 Client Error: Too Many Requests for url: https://api.nlpcloud.io/v1/gpu/gpt-oss-120b/entities: Rate limit: maximum number of requests per hour reached. Please contact support to learn how to increase this limit (if you are on the free plan, we encourage you to subscribe to the pay-as-you-go plan which provides a much higher throughput and many free requests). You can change your plan here: https://nlpcloud.com/home/plans.
