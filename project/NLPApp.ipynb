# %%
import nlpcloud

client = nlpcloud.Client("gpt-oss-120b", "1a260e5d955b2933c02a9d654de116e8a78ab16a", gpu=True)
response = client.entities(
    """John Doe started learning Javascript when he was 15 years old. After a couple of years he switched to Python and starter learning low level programming. He is now a Go expert at Google.""",
    searched_entity="programming languages"
)

response
# Out:
# {'entities': [{'start': 26,
#    'end': 36,
#    'type': 'programming languages',
#    'text': 'Javascript'},
#   {'start': 102,
#    'end': 108,
#    'type': 'programming languages',
#    'text': 'Python'},
#   {'start': 165, 'end': 167, 'type': 'programming languages', 'text': 'Go'}]}

# %%
pip install nlpcloud
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nlpcloud in c:\users\hp\appdata\roaming\python\python313\site-packages (1.1.47)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from nlpcloud) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests->nlpcloud) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->nlpcloud) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->nlpcloud) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->nlpcloud) (2025.4.26)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### OOP Project

# %% [markdown]
# NLPAPP

# %%
class NLPApp : 

    def __init__(self): 
        self.__database = {}
        self.menu()

    def menu(self) : 
        user_input = input("""
        HELLO! how would you like to procede :
        1.Resgister
        2.Already a member? Login 
        3.exit(galti se aagaya)
        """)
        if user_input == "1": 
            self.register()
        elif user_input == "2": 
            self.login()
        else: 
            exit()
            
    def register(self ): 
        name = input("enter name :")
        email = input("enter email: ")
        password = input("enter password")

        if email in self.__database: 
            print("user already exist . login")
            #self.login()
        else: 
            self.__database[email] = [name, password]
            print ( "registered succesfully")
            print(self.__database)
        self.login()
        
    def login(self): 
        email = input("enter email: ")
        password = input("enter password")

        for i in self.__database: 
            if i == email and self.__database[email][1] == password: 
                print("login succesfully")
                self.second_menu()
            else: 
                print("usre doesnot exist register first")
                self.register()
                
    def second_menu(self): 
        user_input = input("""
        Hii which function you want to procede
        1. NER (entity extraction)
        2. Language Detection
        3. Sentiment / Emotion Analysis
        4. Exit (kuch nahi kerna)""")

        if user_input == "1": 
            self.NER()
        elif user_input ==  "2": 
            self.lang_detection()
        elif user_input == "3": 
            self.sentiment()
        else: 
            exit()

    def NER(self): 
        para = input("enter the paragraph you want to check: ")
        search = input("enter the searching word")
        client = nlpcloud.Client("gpt-oss-120b", "1a260e5d955b2933c02a9d654de116e8a78ab16a", gpu=True)
        response = client.entities(para,searched_entity=search)
        
    def lang_detection(self): 
        pass

    def sentiment(self): 
        pass
        
app = NLPApp()
# Out:
#         HELLO! how would you like to procede :
#         1.Resgister
#         2.Already a member? Login
#         3.exit(galti se aagaya)
#          1
# enter name : krish
# enter email:  krish@
# enter password 1234
# registered succesfully
# {'krish@': ['krish', '1234']}
# enter email:  krish@
# enter password 1234
# login succesfully
